# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | sao joao da barra
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | dunedin
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | nouadhibou
# Processing Record 12 of Set 1 | omboue
# Processing Record 13 of Set 1 | itarema
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | mayo
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | maningrida
# Processing Record 20 of Set 1 | mujiayingzi
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | balabac
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | bongaree
# Processing Record 25 of Set 1 | adrar
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | lagoa
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | torbay
# Processing Record 31 of Set 1 | ucluelet
# Processing Record 32 of Set 1 | batemans bay
# Processing Record 33 of Set 1 | osa
# Processing Record 34 of Set 1 | seydi
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | bogo
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | honiara
# Processing Record 43 of Set 1 | fairbanks
# Processing Record 44 of Set 1 | sitka
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | bengkulu
# Processing Record 47 of Set 1 | havoysund
# Processing Record 48 of Set 1 | kargat
# Processing Record 49 of Set 1 | manaus
# Processing Record 50 of Set 1 | andapa
# Processing Record 1 of Set 2 | elko
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | mehamn
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | uglegorsk
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 2 | adilabad
# Processing Record 9 of Set 2 | nanortalik
# Processing Record 10 of Set 2 | high level
# Processing Record 11 of Set 2 | pisco
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | sedhiou
# Processing Record 14 of Set 2 | elk river
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | rongcheng
# Processing Record 17 of Set 2 | belmonte
# Processing Record 18 of Set 2 | newport
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | port augusta
# Processing Record 24 of Set 2 | te anau
# Processing Record 25 of Set 2 | hamilton
# Processing Record 26 of Set 2 | quilmana
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | tsumeb
# Processing Record 29 of Set 2 | sao francisco
# Processing Record 30 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | sept-iles
# Processing Record 33 of Set 2 | bambous virieux
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | kutum
# Processing Record 36 of Set 2 | samarai
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | sao jose da coroa grande
# Processing Record 39 of Set 2 | bonthe
# Processing Record 40 of Set 2 | jhol
# Processing Record 41 of Set 2 | gobabis
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | sur
# Processing Record 46 of Set 2 | soe
# Processing Record 47 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 2 | solikamsk
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | moncton
# Processing Record 1 of Set 3 | mahebourg
# Processing Record 2 of Set 3 | esperance
# Processing Record 3 of Set 3 | nova venecia
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | norman wells
# Processing Record 6 of Set 3 | kruisfontein
# Processing Record 7 of Set 3 | mataura
# Processing Record 8 of Set 3 | winona
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | namie
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | maragogi
# Processing Record 13 of Set 3 | kenai
# Processing Record 14 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 3 | krasnogvardeyskiy
# Processing Record 16 of Set 3 | aksu
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | muisne
# Processing Record 19 of Set 3 | amantea
# Processing Record 20 of Set 3 | soyo
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | swan hill
# Processing Record 23 of Set 3 | oranjemund
# Processing Record 24 of Set 3 | severo-kurilsk
# Processing Record 25 of Set 3 | shimoda
# Processing Record 26 of Set 3 | yumen
# Processing Record 27 of Set 3 | cururupu
# Processing Record 28 of Set 3 | alwar
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | bluff
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | geraldton
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | sola
# Processing Record 35 of Set 3 | riyadh
# Processing Record 36 of Set 3 | baykit
# Processing Record 37 of Set 3 | kajaani
# Processing Record 38 of Set 3 | pangoa
# Processing Record 39 of Set 3 | monte cristi
# City not found. Skipping...
# Processing Record 40 of Set 3 | staryy merchyk
# Processing Record 41 of Set 3 | stamsund
# City not found. Skipping...
# Processing Record 42 of Set 3 | hofn
# Processing Record 43 of Set 3 | wamba
# Processing Record 44 of Set 3 | guiratinga
# Processing Record 45 of Set 3 | nuuk
# Processing Record 46 of Set 3 | denpasar
# Processing Record 47 of Set 3 | male
# Processing Record 48 of Set 3 | pokrovsk
# Processing Record 49 of Set 3 | ishigaki
# Processing Record 50 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | sistranda
# Processing Record 3 of Set 4 | arraial do cabo
# Processing Record 4 of Set 4 | gat
# Processing Record 5 of Set 4 | kavieng
# Processing Record 6 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | rincon
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | dali
# Processing Record 12 of Set 4 | ahipara
# Processing Record 13 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 4 | presidente epitacio
# Processing Record 15 of Set 4 | iqaluit
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | vaini
# Processing Record 18 of Set 4 | businga
# Processing Record 19 of Set 4 | leningradskiy
# Processing Record 20 of Set 4 | winnemucca
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | marawi
# Processing Record 23 of Set 4 | soure
# Processing Record 24 of Set 4 | acari
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | iberia
# Processing Record 27 of Set 4 | matay
# Processing Record 28 of Set 4 | knysna
# Processing Record 29 of Set 4 | rovenki
# Processing Record 30 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 4 | cherskiy
# Processing Record 32 of Set 4 | rawson
# Processing Record 33 of Set 4 | svit
# Processing Record 34 of Set 4 | ilo
# Processing Record 35 of Set 4 | quatre cocos
# Processing Record 36 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 37 of Set 4 | sheridan
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | barcelos
# Processing Record 40 of Set 4 | tamala
# Processing Record 41 of Set 4 | gao
# Processing Record 42 of Set 4 | aranos
# Processing Record 43 of Set 4 | pacific grove
# Processing Record 44 of Set 4 | hede
# Processing Record 45 of Set 4 | cabedelo
# Processing Record 46 of Set 4 | corinto
# Processing Record 47 of Set 4 | sisimiut
# Processing Record 48 of Set 4 | saiki
# Processing Record 49 of Set 4 | ponta delgada
# Processing Record 50 of Set 4 | cumana
# Processing Record 1 of Set 5 | clyde river
# Processing Record 2 of Set 5 | lalomanu
# City not found. Skipping...
# Processing Record 3 of Set 5 | nuristan
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | shieli
# Processing Record 6 of Set 5 | mount gambier
# Processing Record 7 of Set 5 | ulladulla
# Processing Record 8 of Set 5 | laizhou
# Processing Record 9 of Set 5 | atbasar
# Processing Record 10 of Set 5 | orapa
# Processing Record 11 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 5 | narsaq
# Processing Record 13 of Set 5 | bam
# Processing Record 14 of Set 5 | bagdarin
# Processing Record 15 of Set 5 | lumding
# Processing Record 16 of Set 5 | beloha
# Processing Record 17 of Set 5 | nome
# Processing Record 18 of Set 5 | tongren
# Processing Record 19 of Set 5 | itoman
# Processing Record 20 of Set 5 | nakhon thai
# Processing Record 21 of Set 5 | tokur
# Processing Record 22 of Set 5 | qaqortoq
# Processing Record 23 of Set 5 | kota kinabalu
# Processing Record 24 of Set 5 | helena
# Processing Record 25 of Set 5 | bom jardim
# Processing Record 26 of Set 5 | neijiang
# Processing Record 27 of Set 5 | eyl
# Processing Record 28 of Set 5 | albemarle
# Processing Record 29 of Set 5 | isangel
# Processing Record 30 of Set 5 | ust-kuyga
# Processing Record 31 of Set 5 | obo
# Processing Record 32 of Set 5 | mackay
# Processing Record 33 of Set 5 | matara
# Processing Record 34 of Set 5 | caravelas
# Processing Record 35 of Set 5 | port macquarie
# Processing Record 36 of Set 5 | georgetown
# Processing Record 37 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 5 | dukat
# Processing Record 39 of Set 5 | hobyo
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | malmesbury
# Processing Record 42 of Set 5 | mosjoen
# Processing Record 43 of Set 5 | mangotsfield
# Processing Record 44 of Set 5 | bay roberts
# Processing Record 45 of Set 5 | fare
# Processing Record 46 of Set 5 | masuda
# Processing Record 47 of Set 5 | griffith
# Processing Record 48 of Set 5 | skibbereen
# Processing Record 49 of Set 5 | amiens
# Processing Record 50 of Set 5 | saint anthony
# Processing Record 1 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 6 | dubai
# Processing Record 3 of Set 6 | pleasanton
# Processing Record 4 of Set 6 | roma
# Processing Record 5 of Set 6 | lunglei
# Processing Record 6 of Set 6 | hualmay
# Processing Record 7 of Set 6 | wolkersdorf
# Processing Record 8 of Set 6 | half moon bay
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | scottsbluff
# Processing Record 11 of Set 6 | miri
# Processing Record 12 of Set 6 | carlsbad
# Processing Record 13 of Set 6 | gorin
# Processing Record 14 of Set 6 | derzhavinsk
# Processing Record 15 of Set 6 | luanda
# Processing Record 16 of Set 6 | umm lajj
# Processing Record 17 of Set 6 | icod de los vinos
# Processing Record 18 of Set 6 | faanui
# Processing Record 19 of Set 6 | airai
# Processing Record 20 of Set 6 | east london
# Processing Record 21 of Set 6 | abramovka
# Processing Record 22 of Set 6 | minab
# Processing Record 23 of Set 6 | vila velha
# Processing Record 24 of Set 6 | inuvik
# Processing Record 25 of Set 6 | san quintin
# Processing Record 26 of Set 6 | oyama
# Processing Record 27 of Set 6 | hulan
# Processing Record 28 of Set 6 | san sebastian
# Processing Record 29 of Set 6 | spornoye
# Processing Record 30 of Set 6 | pevek
# Processing Record 31 of Set 6 | hays
# Processing Record 32 of Set 6 | angoche
# Processing Record 33 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 6 | sarkand
# Processing Record 36 of Set 6 | kiruna
# Processing Record 37 of Set 6 | awjilah
# Processing Record 38 of Set 6 | sao borja
# Processing Record 39 of Set 6 | portland
# Processing Record 40 of Set 6 | hirara
# Processing Record 41 of Set 6 | dahegam
# Processing Record 42 of Set 6 | mizdah
# Processing Record 43 of Set 6 | odweyne
# Processing Record 44 of Set 6 | paita
# Processing Record 45 of Set 6 | dong xoai
# Processing Record 46 of Set 6 | cidreira
# Processing Record 47 of Set 6 | guerrero negro
# Processing Record 48 of Set 6 | divnogorsk
# Processing Record 49 of Set 6 | caucaia
# Processing Record 50 of Set 6 | sechura
# Processing Record 1 of Set 7 | olafsvik
# Processing Record 2 of Set 7 | kabare
# Processing Record 3 of Set 7 | luganville
# Processing Record 4 of Set 7 | puerto madryn
# Processing Record 5 of Set 7 | wagar
# Processing Record 6 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 7 | najran
# Processing Record 8 of Set 7 | vao
# Processing Record 9 of Set 7 | vila franca do campo
# Processing Record 10 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 7 | necochea
# Processing Record 13 of Set 7 | shuangcheng
# Processing Record 14 of Set 7 | kalabo
# Processing Record 15 of Set 7 | port blair
# Processing Record 16 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 7 | northam
# Processing Record 18 of Set 7 | karpathos
# Processing Record 19 of Set 7 | ayan
# Processing Record 20 of Set 7 | kem
# Processing Record 21 of Set 7 | turek
# Processing Record 22 of Set 7 | toora-khem
# Processing Record 23 of Set 7 | namatanai
# Processing Record 24 of Set 7 | north bend
# Processing Record 25 of Set 7 | yar-sale
# Processing Record 26 of Set 7 | shenjiamen
# Processing Record 27 of Set 7 | touros
# Processing Record 28 of Set 7 | padang
# Processing Record 29 of Set 7 | blackfoot
# Processing Record 30 of Set 7 | mayya
# Processing Record 31 of Set 7 | superior
# Processing Record 32 of Set 7 | tecoanapa
# Processing Record 33 of Set 7 | churapcha
# Processing Record 34 of Set 7 | mporokoso
# Processing Record 35 of Set 7 | mansa
# Processing Record 36 of Set 7 | george town
# Processing Record 37 of Set 7 | miramar
# Processing Record 38 of Set 7 | baishishan
# Processing Record 39 of Set 7 | suditi
# Processing Record 40 of Set 7 | le locle
# Processing Record 41 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 7 | danielskuil
# Processing Record 43 of Set 7 | uravakonda
# Processing Record 44 of Set 7 | taltal
# Processing Record 45 of Set 7 | komsomolskiy
# Processing Record 46 of Set 7 | puerto leguizamo
# Processing Record 47 of Set 7 | buala
# Processing Record 48 of Set 7 | namibe
# Processing Record 49 of Set 7 | suchitlan
# Processing Record 50 of Set 7 | agutaya
# Processing Record 1 of Set 8 | temba
# Processing Record 2 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 8 | santa maria
# Processing Record 4 of Set 8 | verkhnyaya toyma
# Processing Record 5 of Set 8 | meulaboh
# Processing Record 6 of Set 8 | alice springs
# Processing Record 7 of Set 8 | chalmette
# Processing Record 8 of Set 8 | jabinyanah
# Processing Record 9 of Set 8 | el sauce
# Processing Record 10 of Set 8 | xining
# Processing Record 11 of Set 8 | stranda
# Processing Record 12 of Set 8 | saint-ambroise
# Processing Record 13 of Set 8 | kahului
# Processing Record 14 of Set 8 | requena
# Processing Record 15 of Set 8 | chicama
# Processing Record 16 of Set 8 | laibin
# Processing Record 17 of Set 8 | alassio
# Processing Record 18 of Set 8 | dongsheng
# Processing Record 19 of Set 8 | reyes
# Processing Record 20 of Set 8 | aktash
# Processing Record 21 of Set 8 | hasaki
# Processing Record 22 of Set 8 | boa vista
# Processing Record 23 of Set 8 | taloqan
# Processing Record 24 of Set 8 | saldanha
# Processing Record 25 of Set 8 | kashary
# Processing Record 26 of Set 8 | carpentras
# Processing Record 27 of Set 8 | fortuna
# Processing Record 28 of Set 8 | taoudenni
# Processing Record 29 of Set 8 | cayenne
# Processing Record 30 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 8 | takoradi
# Processing Record 32 of Set 8 | todos santos
# Processing Record 33 of Set 8 | grindavik
# Processing Record 34 of Set 8 | lokoja
# Processing Record 35 of Set 8 | balkanabat
# Processing Record 36 of Set 8 | dudinka
# Processing Record 37 of Set 8 | koungou
# Processing Record 38 of Set 8 | san luis
# Processing Record 39 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 8 | kaseda
# Processing Record 41 of Set 8 | broome
# Processing Record 42 of Set 8 | turukhansk
# Processing Record 43 of Set 8 | yumbe
# Processing Record 44 of Set 8 | la ronge
# Processing Record 45 of Set 8 | rio formoso
# Processing Record 46 of Set 8 | guljanci
# City not found. Skipping...
# Processing Record 47 of Set 8 | berezovka
# Processing Record 48 of Set 8 | zabol
# Processing Record 49 of Set 8 | broken hill
# Processing Record 50 of Set 8 | aklavik
# Processing Record 1 of Set 9 | matagami
# Processing Record 2 of Set 9 | burica
# City not found. Skipping...
# Processing Record 3 of Set 9 | ternate
# Processing Record 4 of Set 9 | cookeville
# Processing Record 5 of Set 9 | peniche
# Processing Record 6 of Set 9 | trebisacce
# Processing Record 7 of Set 9 | gaziantep
# Processing Record 8 of Set 9 | bac lieu
# Processing Record 9 of Set 9 | sooke
# Processing Record 10 of Set 9 | san cristobal
# Processing Record 11 of Set 9 | brae
# Processing Record 12 of Set 9 | haines junction
# Processing Record 13 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 14 of Set 9 | abu jubayhah
# City not found. Skipping...
# Processing Record 15 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 16 of Set 9 | limbe
# Processing Record 17 of Set 9 | tabuk
# Processing Record 18 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 19 of Set 9 | inhambane
# Processing Record 20 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 9 | sungaipenuh
# Processing Record 22 of Set 9 | collie
# Processing Record 23 of Set 9 | flinders
# Processing Record 24 of Set 9 | arlit
# Processing Record 25 of Set 9 | saint george
# Processing Record 26 of Set 9 | kango
# Processing Record 27 of Set 9 | serro
# Processing Record 28 of Set 9 | tigil
# Processing Record 29 of Set 9 | sokoni
# Processing Record 30 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 9 | aripuana
# Processing Record 32 of Set 9 | dhidhdhoo
# Processing Record 33 of Set 9 | wau
# Processing Record 34 of Set 9 | ewa beach
# Processing Record 35 of Set 9 | honolulu
# Processing Record 36 of Set 9 | lorengau
# Processing Record 37 of Set 9 | concepcion del oro
# Processing Record 38 of Set 9 | port lincoln
# Processing Record 39 of Set 9 | rio grande
# Processing Record 40 of Set 9 | port hedland
# Processing Record 41 of Set 9 | richards bay
# Processing Record 42 of Set 9 | ponta do sol
# Processing Record 43 of Set 9 | constantine
# Processing Record 44 of Set 9 | masty
# Processing Record 45 of Set 9 | muros
# Processing Record 46 of Set 9 | wasilla
# Processing Record 47 of Set 9 | amudat
# Processing Record 48 of Set 9 | bani
# Processing Record 49 of Set 9 | dawei
# Processing Record 50 of Set 9 | salalah
# Processing Record 1 of Set 10 | gravdal
# Processing Record 2 of Set 10 | vyartsilya
# Processing Record 3 of Set 10 | morococha
# Processing Record 4 of Set 10 | vardo
# Processing Record 5 of Set 10 | san policarpo
# Processing Record 6 of Set 10 | westport
# Processing Record 7 of Set 10 | fukue
# Processing Record 8 of Set 10 | uruacu
# Processing Record 9 of Set 10 | sandakan
# Processing Record 10 of Set 10 | tagab
# Processing Record 11 of Set 10 | coos bay
# Processing Record 12 of Set 10 | vanimo
# Processing Record 13 of Set 10 | magdagachi
# Processing Record 14 of Set 10 | saurimo
# Processing Record 15 of Set 10 | ibra
# Processing Record 16 of Set 10 | ulaanbaatar
# Processing Record 17 of Set 10 | dicabisagan
# Processing Record 18 of Set 10 | cerritos
# Processing Record 19 of Set 10 | tazovskiy
# Processing Record 20 of Set 10 | ust-kulom
# Processing Record 21 of Set 10 | maridi
# Processing Record 22 of Set 10 | nyuzen
# Processing Record 23 of Set 10 | srednekolymsk
# Processing Record 24 of Set 10 | great yarmouth
# Processing Record 25 of Set 10 | salym
# Processing Record 26 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 28 of Set 10 | ndele
# Processing Record 29 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 10 | plettenberg bay
# Processing Record 31 of Set 10 | kargasok
# Processing Record 32 of Set 10 | saint-joseph
# Processing Record 33 of Set 10 | bereda
# Processing Record 34 of Set 10 | kununurra
# Processing Record 35 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 10 | svetlogorsk
# Processing Record 37 of Set 10 | axim
# Processing Record 38 of Set 10 | palmer
# Processing Record 39 of Set 10 | pierre
# Processing Record 40 of Set 10 | luderitz
# Processing Record 41 of Set 10 | wadi maliz
# Processing Record 42 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 10 | tuatapere
# Processing Record 44 of Set 10 | santa luzia
# Processing Record 45 of Set 10 | varzea alegre
# Processing Record 46 of Set 10 | lompoc
# Processing Record 47 of Set 10 | gejiu
# Processing Record 48 of Set 10 | novoilinsk
# Processing Record 49 of Set 10 | yurla
# Processing Record 50 of Set 10 | jalapa
# Processing Record 1 of Set 11 | manuk mangkaw
# Processing Record 2 of Set 11 | maceio
# Processing Record 3 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 4 of Set 11 | kalemie
# Processing Record 5 of Set 11 | batagay-alyta
# Processing Record 6 of Set 11 | stabat
# Processing Record 7 of Set 11 | khandyga
# Processing Record 8 of Set 11 | ipora
# Processing Record 9 of Set 11 | yaan
# Processing Record 10 of Set 11 | prainha
# Processing Record 11 of Set 11 | mount isa
# Processing Record 12 of Set 11 | oksfjord
# Processing Record 13 of Set 11 | vostok
# Processing Record 14 of Set 11 | hailey
# Processing Record 15 of Set 11 | sabang
# Processing Record 16 of Set 11 | digri
# Processing Record 17 of Set 11 | aswan
# Processing Record 18 of Set 11 | thunder bay
# Processing Record 19 of Set 11 | vestmannaeyjar
# Processing Record 20 of Set 11 | chimore
# Processing Record 21 of Set 11 | caconda
# Processing Record 22 of Set 11 | balaipungut
# Processing Record 23 of Set 11 | salta
# Processing Record 24 of Set 11 | ponca city
# Processing Record 25 of Set 11 | comitancillo
# Processing Record 26 of Set 11 | banda aceh
# Processing Record 27 of Set 11 | berlevag
# Processing Record 28 of Set 11 | coahuayana
# Processing Record 29 of Set 11 | pangai
# Processing Record 30 of Set 11 | port hardy
# Processing Record 31 of Set 11 | bogande
# Processing Record 32 of Set 11 | sinnamary
# Processing Record 33 of Set 11 | waipawa
# Processing Record 34 of Set 11 | cusuna
# Processing Record 35 of Set 11 | carballo
# Processing Record 36 of Set 11 | catuday
# Processing Record 37 of Set 11 | karakol
# Processing Record 38 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 39 of Set 11 | kuusamo
# Processing Record 40 of Set 11 | kalambaka
# Processing Record 41 of Set 11 | george
# Processing Record 42 of Set 11 | simpang
# Processing Record 43 of Set 11 | ardakan
# Processing Record 44 of Set 11 | kavaratti
# Processing Record 45 of Set 11 | garissa
# Processing Record 46 of Set 11 | togur
# Processing Record 47 of Set 11 | evanston
# Processing Record 48 of Set 11 | atambua
# Processing Record 49 of Set 11 | cienfuegos
# Processing Record 50 of Set 11 | saint-augustin
# Processing Record 1 of Set 12 | nanuque
# Processing Record 2 of Set 12 | lazaro cardenas
# Processing Record 3 of Set 12 | vylkove
# Processing Record 4 of Set 12 | kidal
# Processing Record 5 of Set 12 | jequitinhonha
# Processing Record 6 of Set 12 | zabid
# Processing Record 7 of Set 12 | yoichi
# Processing Record 8 of Set 12 | cabo san lucas
# Processing Record 9 of Set 12 | pandamatenga
# Processing Record 10 of Set 12 | sakaraha
# Processing Record 11 of Set 12 | road town
# Processing Record 12 of Set 12 | bilma
# Processing Record 13 of Set 12 | krutinka
# Processing Record 14 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 15 of Set 12 | akyab
# Processing Record 16 of Set 12 | walvis bay
# Processing Record 17 of Set 12 | saint-paul
# Processing Record 18 of Set 12 | pennadam
# Processing Record 19 of Set 12 | maniitsoq
# Processing Record 20 of Set 12 | tura
# Processing Record 21 of Set 12 | muzquiz
# City not found. Skipping...
# Processing Record 22 of Set 12 | navalcarnero
# Processing Record 23 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 12 | navalmoral de la mata
# Processing Record 25 of Set 12 | vitim
# Processing Record 26 of Set 12 | palaikastron
# Processing Record 27 of Set 12 | koslan
# Processing Record 28 of Set 12 | lasa
# Processing Record 29 of Set 12 | agadez
# Processing Record 30 of Set 12 | ayabaca
# Processing Record 31 of Set 12 | zhigansk
# Processing Record 32 of Set 12 | sompeta
# Processing Record 33 of Set 12 | andenes
# Processing Record 34 of Set 12 | gisborne
# Processing Record 35 of Set 12 | seoul
# Processing Record 36 of Set 12 | tarko-sale
# Processing Record 37 of Set 12 | fort-shevchenko
# Processing Record 38 of Set 12 | huarmey
# Processing Record 39 of Set 12 | kieta
# Processing Record 40 of Set 12 | asau
# Processing Record 41 of Set 12 | pangkalanbuun
# Processing Record 42 of Set 12 | rozkishne
# Processing Record 43 of Set 12 | yulara
# Processing Record 44 of Set 12 | waingapu
# Processing Record 45 of Set 12 | noyabrsk
# Processing Record 46 of Set 12 | raychikhinsk
# Processing Record 47 of Set 12 | enugu
# Processing Record 48 of Set 12 | mitchell
# Processing Record 49 of Set 12 | bellavista
# Processing Record 50 of Set 12 | kribi
# Processing Record 1 of Set 13 | lumut
# Processing Record 2 of Set 13 | lagos
# Processing Record 3 of Set 13 | sibolga
# Processing Record 4 of Set 13 | kuloy
# Processing Record 5 of Set 13 | turbat
# Processing Record 6 of Set 13 | bloemfontein
# Processing Record 7 of Set 13 | banjar
# Processing Record 8 of Set 13 | awka
# Processing Record 9 of Set 13 | papar
# Processing Record 10 of Set 13 | yerkoy
# Processing Record 11 of Set 13 | vrangel
# Processing Record 12 of Set 13 | valparaiso
# Processing Record 13 of Set 13 | iquique
# Processing Record 14 of Set 13 | palu
# Processing Record 15 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 13 | betlitsa
# Processing Record 17 of Set 13 | tumalim
# Processing Record 18 of Set 13 | dalmatovo
# Processing Record 19 of Set 13 | toro
# Processing Record 20 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 21 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 13 | russell
# Processing Record 23 of Set 13 | devli
# Processing Record 24 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 13 | constitucion
# Processing Record 26 of Set 13 | san rafael
# Processing Record 27 of Set 13 | antipolo
# Processing Record 28 of Set 13 | sawakin
# Processing Record 29 of Set 13 | novoagansk
# Processing Record 30 of Set 13 | babati
# Processing Record 31 of Set 13 | tuy hoa
# Processing Record 32 of Set 13 | fengzhen
# Processing Record 33 of Set 13 | saint quentin
# City not found. Skipping...
# Processing Record 34 of Set 13 | storsteinnes
# Processing Record 35 of Set 13 | gursahaiganj
# Processing Record 36 of Set 13 | nelson bay
# Processing Record 37 of Set 13 | tarusa
# Processing Record 38 of Set 13 | tual
# Processing Record 39 of Set 13 | la palma
# Processing Record 40 of Set 13 | hanna
# Processing Record 41 of Set 13 | arvi
# Processing Record 42 of Set 13 | karaton
# Processing Record 43 of Set 13 | rosarito
# Processing Record 44 of Set 13 | baran
# Processing Record 45 of Set 13 | puqi
# Processing Record 46 of Set 13 | ruston
# Processing Record 47 of Set 13 | opuwo
# Processing Record 48 of Set 13 | abnub
# Processing Record 49 of Set 13 | hakui
# Processing Record 50 of Set 13 | sanming
# Processing Record 1 of Set 14 | montepuez
# Processing Record 2 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 3 of Set 14 | nishihara
# Processing Record 4 of Set 14 | raudeberg
# Processing Record 5 of Set 14 | evensk
# Processing Record 6 of Set 14 | zaysan
# Processing Record 7 of Set 14 | karasuk
# Processing Record 8 of Set 14 | goderich
# Processing Record 9 of Set 14 | price
# Processing Record 10 of Set 14 | kristianstad
# Processing Record 11 of Set 14 | slave lake
# Processing Record 12 of Set 14 | zhangjiakou
# Processing Record 13 of Set 14 | nirgua
# Processing Record 14 of Set 14 | talcahuano
# Processing Record 15 of Set 14 | whitehorse
# Processing Record 16 of Set 14 | makakilo city
# Processing Record 17 of Set 14 | ferrol
# Processing Record 18 of Set 14 | sekoma
# Processing Record 19 of Set 14 | lithakia
# Processing Record 20 of Set 14 | nuevitas
# Processing Record 21 of Set 14 | mariental
# Processing Record 22 of Set 14 | jalu
# Processing Record 23 of Set 14 | campos
# Processing Record 24 of Set 14 | pringsewu
# Processing Record 25 of Set 14 | stephenville
# Processing Record 26 of Set 14 | atar
# Processing Record 27 of Set 14 | deputatskiy
# Processing Record 28 of Set 14 | imbituba
# Processing Record 29 of Set 14 | poddorye
# Processing Record 30 of Set 14 | bud
# Processing Record 31 of Set 14 | lucea
# Processing Record 32 of Set 14 | hope mills
# Processing Record 33 of Set 14 | contamana
# Processing Record 34 of Set 14 | riviere-au-renard
# Processing Record 35 of Set 14 | almaznyy
# Processing Record 36 of Set 14 | upington
# Processing Record 37 of Set 14 | harper
# Processing Record 38 of Set 14 | effium
# Processing Record 39 of Set 14 | alpena
# Processing Record 40 of Set 14 | darnetal
# Processing Record 41 of Set 14 | yueyang
# Processing Record 42 of Set 14 | roald
# Processing Record 43 of Set 14 | chapais
# Processing Record 44 of Set 14 | kamaishi
# Processing Record 45 of Set 14 | ambilobe
# Processing Record 46 of Set 14 | alofi
# Processing Record 47 of Set 14 | santiago del estero
# Processing Record 48 of Set 14 | faya
# Processing Record 49 of Set 14 | vanavara
# Processing Record 50 of Set 14 | hearst
# Processing Record 1 of Set 15 | waspan
# Processing Record 2 of Set 15 | kurumkan
# Processing Record 3 of Set 15 | shimanovsk
# Processing Record 4 of Set 15 | aasiaat
# Processing Record 5 of Set 15 | macau
# Processing Record 6 of Set 15 | mancio lima
# Processing Record 7 of Set 15 | rudnogorsk
# Processing Record 8 of Set 15 | honningsvag
# Processing Record 9 of Set 15 | erzin
# Processing Record 10 of Set 15 | arman
# Processing Record 11 of Set 15 | desaguadero
# Processing Record 12 of Set 15 | bedele
# Processing Record 13 of Set 15 | atasu
# Processing Record 14 of Set 15 | francavilla al mare
# Processing Record 15 of Set 15 | ketchikan
# Processing Record 16 of Set 15 | kupang
# Processing Record 17 of Set 15 | hami
# Processing Record 18 of Set 15 | loukhi
# Processing Record 19 of Set 15 | doka
# Processing Record 20 of Set 15 | lilongwe
# Processing Record 21 of Set 15 | saravan
# Processing Record 22 of Set 15 | port-gentil
# Processing Record 23 of Set 15 | kiama
# Processing Record 24 of Set 15 | tamara
# Processing Record 25 of Set 15 | moree
# Processing Record 26 of Set 15 | fonte boa
# Processing Record 27 of Set 15 | jiuquan
# Processing Record 28 of Set 15 | amahai
# Processing Record 29 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 30 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 15 | borba
# Processing Record 32 of Set 15 | nenjiang
# Processing Record 33 of Set 15 | teguise
# Processing Record 34 of Set 15 | emerald
# Processing Record 35 of Set 15 | beringovskiy
# Processing Record 36 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 37 of Set 15 | pangnirtung
# Processing Record 38 of Set 15 | iroquois falls
# Processing Record 39 of Set 15 | suao
# City not found. Skipping...
# Processing Record 40 of Set 15 | juba
# Processing Record 41 of Set 15 | banepa
# Processing Record 42 of Set 15 | biak
# Processing Record 43 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 44 of Set 15 | mundra
# Processing Record 45 of Set 15 | farmington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Hilo  19.7297 -155.0900     80.33        73          20
# 1  Sao Joao Da Barra -21.6403  -41.0511     68.07        73          99
# 2             Hobart -42.8794  147.3294     72.01        54          40
# 3              Tiksi  71.6872  128.8694    -16.29        99          98
# 4            Dunedin -45.8742  170.5036     52.54        82         100
# 5             Avarua -21.2078 -159.7750     82.45        69          75
# 6               Lebu -37.6167  -73.6500     54.41        92          73
# 7       Punta Arenas -53.1500  -70.9167     39.31        75          75
# 8         Bredasdorp -34.5322   20.0403     63.28        88         100
# 9      Mar Del Plata -38.0023  -57.5575     62.87        80           0
#
#    Wind Speed Country Current Description
# 0       10.36      US          few clouds
# 1        6.87      BR     overcast clouds
# 2        1.01      AU    scattered clouds
# 3        0.94      RU     overcast clouds
# 4        4.74      NZ     overcast clouds
# 5        3.44      CK          light rain
# 6       18.63      CL       broken clouds
# 7       25.32      CL       broken clouds
# 8       15.03      ZA          light rain
# 9        5.37      AR           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Hilo      US  19.7297 -155.0900     80.33        73
# 1  Sao Joao Da Barra      BR -21.6403  -41.0511     68.07        73
# 2             Hobart      AU -42.8794  147.3294     72.01        54
# 3              Tiksi      RU  71.6872  128.8694    -16.29        99
# 4            Dunedin      NZ -45.8742  170.5036     52.54        82
# 5             Avarua      CK -21.2078 -159.7750     82.45        69
# 6               Lebu      CL -37.6167  -73.6500     54.41        92
# 7       Punta Arenas      CL -53.1500  -70.9167     39.31        75
# 8         Bredasdorp      ZA -34.5322   20.0403     63.28        88
# 9      Mar Del Plata      AR -38.0023  -57.5575     62.87        80
#
#    Cloudiness  Wind Speed Current Description
# 0          20       10.36          few clouds
# 1          99        6.87     overcast clouds
# 2          40        1.01    scattered clouds
# 3          98        0.94     overcast clouds
# 4         100        4.74     overcast clouds
# 5          75        3.44          light rain
# 6          73       18.63       broken clouds
# 7          75       25.32       broken clouds
# 8         100       15.03          light rain
# 9           0        5.37           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
